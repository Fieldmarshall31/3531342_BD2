# %% [markdown]
# # **APPENDIX**

# %% [markdown]
# # **SECTION 1: Brief Introduction**

# %% [markdown]
# ## **1.1: About JC Penney**

# %% [markdown]
# JC Penney is a retail store that offers a wide range of consumer products which includes fahion, home goods, and accessories.

# %% [markdown]
# ## **1.2: Aim of Assignment**

# %% [markdown]
# The aim of this assignment is to analyse JC Penney's data files and generate actionable business insights that can support making data driven decisions for the business.

# %% [markdown]
# # **SECTION 2: Loading and Understanding the Data**

# %% [markdown]
# ## **2.1: Brief Overview**

# %% [markdown]
# The JC Penney Dataset consists of the following CSV and JSON files which are related to JC Penney's Online Retail Platform.
#
# They are as follows;
#
#
# *   products.csv
# *   reviews.csv
# *   users.csv
# *   jcpenney_products.json
# *   jcpenney_reviewers.json
#
# Now, let's go ahead to load them here and understand the data set we would be working with.

# %% [markdown]
# ## **2.2: Importing the Required Libraries**

# %%
import pandas as pd               # for data manipulation and analysis
import json                       # for reading the json files
import matplotlib.pyplot as plt   # for data visualisation
import seaborn as sns             # for cleaner data visualisation

# %% [markdown]
# ## **2.3: Loading the Data Files**

# %% [markdown]
# ### **2.3.1:  Accessing the Data Files from my Google Drive**

# %%
# enable access to my Google Drive
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# defined path to the folder where the assignment files are stored
path = '/content/drive/MyDrive/ITNPBD2_Spring2026_Assignment/Data_Files'

# change the working directory to the specified folder
os.chdir(path)

# list of all the files in the specified folder
os.listdir()
# Out:
# ['users.csv',
#  'reviews.csv',
#  'jcpenney_products.json',
#  'products.csv',
#  'jcpenney_reviewers.json']

# %% [markdown]
# ### **2.3.2:  Reading the CSV Data Files Using Pandas**

# %%
products = pd.read_csv('products.csv')  # read the product csv files
reviews = pd.read_csv('reviews.csv')    # read the review csv files
users = pd.read_csv('users.csv')        # read the users csv files

# number of rows (records) and columns (attributes)
# in each data set
print("Products shape:", products.shape)
print("Reviews shape:", reviews.shape)
print("Users shape:", users.shape)
# Out:
# Products shape: (7982, 6)
# Reviews shape: (39063, 4)
# Users shape: (5000, 3)

# %% [markdown]
# ### **2.3.3:  Reading the Products.JSON File**

# %%
# empty list to store each JSON objects
products_json = []

# open the JSON file in read mode and ensure it closes automatically after reading
with open('jcpenney_products.json', 'r') as f:
    for line in f: # read the file line by line
          # convert JSON text to a Python dictionary and append to the list
          products_json.append(json.loads(line))

# convert the appended list of dictionaries into a pandas DataFrame
products_df = pd.DataFrame(products_json)

# number of rows (records) and columns (attributes)
# in the Products_df
print("Products_df shape:", products_df.shape)
# Out:
# Products_df shape: (7982, 15)

# %% [markdown]
# ### **2.3.4:  Reading the Reviewers.JSON File**

# %%
# empty list to store each JSON objects
reviewers_json = []

# open the JSON file in read mode and ensure it closes automatically after reading
with open('jcpenney_reviewers.json', 'r') as f:
    for line in f: # read the file line by line
          # convert JSON text to a Python dictionary and append to the list
          reviewers_json.append(json.loads(line))

# convert the appended list of dictionaries into a pandas DataFrame
reviewers_df = pd.DataFrame(reviewers_json)

# number of rows (records) and columns (attributes)
# in the Reviewers_df
print("reviewers_df shape:", reviewers_df.shape)
# Out:
# reviewers_df shape: (5000, 4)

# %% [markdown]
# ## **2.4:  Displaying the first 5 rows (records) of each loaded data files**

# %%
products.head()
# Out:
#                             Uniq_id           SKU  \
# 0  b6c0b6bea69c722939585baeac73c13d  pp5006380337
# 1  93e5272c51d8cce02597e3ce67b7ad0a  pp5006380337
# 2  013e320f2f2ec0cf5b3ff5418d688528  pp5006380337
# 3  505e6633d81f2cb7400c0cfa0394c427  pp5006380337
# 4  d969a8542122e1331e304b09f81a83f6  pp5006380337
#
#                                           Name  \
# 0  Alfred Dunner® Essential Pull On Capri Pant
# 1  Alfred Dunner® Essential Pull On Capri Pant
# 2  Alfred Dunner® Essential Pull On Capri Pant
# 3  Alfred Dunner® Essential Pull On Capri Pant
# 4  Alfred Dunner® Essential Pull On Capri Pant
#
#                                          Description  Price  Av_Score
# 0  Youll return to our Alfred Dunner pull-on capr...  41.09     2.625
# 1  Youll return to our Alfred Dunner pull-on capr...  41.09     3.000
# 2  Youll return to our Alfred Dunner pull-on capr...  41.09     2.625
# 3  Youll return to our Alfred Dunner pull-on capr...  41.09     3.500
# 4  Youll return to our Alfred Dunner pull-on capr...  41.09     3.125

# %%
reviews.head()
# Out:
#                             Uniq_id  Username  Score  \
# 0  b6c0b6bea69c722939585baeac73c13d  fsdv4141      2
# 1  b6c0b6bea69c722939585baeac73c13d  krpz1113      1
# 2  b6c0b6bea69c722939585baeac73c13d  mbmg3241      2
# 3  b6c0b6bea69c722939585baeac73c13d  zeqg1222      0
# 4  b6c0b6bea69c722939585baeac73c13d  nvfn3212      3
#
#                                               Review
# 0  You never have to worry about the fit...Alfred...
# 1  Good quality fabric. Perfect fit. Washed very ...
# 2  I do not normally wear pants or capris that ha...
# 3  I love these capris! They fit true to size and...
# 4  This product is very comfortable and the fabri...

# %%
users.head()
# Out:
#    Username         DOB          State
# 0  bkpn1412  31.07.1983         Oregon
# 1  gqjs4414  27.07.1998  Massachusetts
# 2  eehe1434  08.08.1950          Idaho
# 3  hkxj1334  03.08.1969        Florida
# 4  jjbd1412  26.07.2001        Georgia

# %%
products_df.head()
# Out:
#                             uniq_id           sku  \
# 0  b6c0b6bea69c722939585baeac73c13d  pp5006380337
# 1  93e5272c51d8cce02597e3ce67b7ad0a  pp5006380337
# 2  013e320f2f2ec0cf5b3ff5418d688528  pp5006380337
# 3  505e6633d81f2cb7400c0cfa0394c427  pp5006380337
# 4  d969a8542122e1331e304b09f81a83f6  pp5006380337
#
#                                     name_title  \
# 0  Alfred Dunner® Essential Pull On Capri Pant
# 1  Alfred Dunner® Essential Pull On Capri Pant
# 2  Alfred Dunner® Essential Pull On Capri Pant
# 3  Alfred Dunner® Essential Pull On Capri Pant
# 4  Alfred Dunner® Essential Pull On Capri Pant
#
#                                          description list_price sale_price  \
# 0  You'll return to our Alfred Dunner pull-on cap...      41.09      24.16
# 1  You'll return to our Alfred Dunner pull-on cap...      41.09      24.16
# 2  You'll return to our Alfred Dunner pull-on cap...      41.09      24.16
# 3  You'll return to our Alfred Dunner pull-on cap...      41.09      24.16
# 4  You'll return to our Alfred Dunner pull-on cap...      41.09      24.16
#
#         category                 category_tree  average_product_rating  \
# 0  alfred dunner  jcpenney|women|alfred dunner                   2.625
# 1  alfred dunner  jcpenney|women|alfred dunner                   3.000
# 2       view all       jcpenney|women|view all                   2.625
# 3       view all       jcpenney|women|view all                   3.500
# 4       view all       jcpenney|women|view all                   3.125
#
#                                          product_url  \
# 0  http://www.jcpenney.com/alfred-dunner-essentia...
# 1  http://www.jcpenney.com/alfred-dunner-essentia...
# 2  http://www.jcpenney.com/alfred-dunner-essentia...
# 3  http://www.jcpenney.com/alfred-dunner-essentia...
# 4  http://www.jcpenney.com/alfred-dunner-essentia...
#
#                                   product_image_urls          brand  \
# 0  http://s7d9.scene7.com/is/image/JCPenney/DP122...  Alfred Dunner
# 1  http://s7d9.scene7.com/is/image/JCPenney/DP122...  Alfred Dunner
# 2  http://s7d9.scene7.com/is/image/JCPenney/DP122...  Alfred Dunner
# 3  http://s7d9.scene7.com/is/image/JCPenney/DP122...  Alfred Dunner
# 4  http://s7d9.scene7.com/is/image/JCPenney/DP122...  Alfred Dunner
#
#    total_number_reviews                                            Reviews  \
# 0                     8  [{'User': 'fsdv4141', 'Review': 'You never hav...
# 1                     8  [{'User': 'tpcu2211', 'Review': 'You never hav...
# 2                     8  [{'User': 'pcfg3234', 'Review': 'You never hav...
# 3                     8  [{'User': 'ngrq4411', 'Review': 'You never hav...
# 4                     8  [{'User': 'nbmi2334', 'Review': 'You never hav...
#
#                                          Bought With
# 0  [898e42fe937a33e8ce5e900ca7a4d924, 8c02c262567...
# 1  [bc9ab3406dcaa84a123b9da862e6367d, 18eb69e8fc2...
# 2  [3ce70f519a9cfdd85cdbdecd358e5347, b0295c96d2b...
# 3  [efcd811edccbeb5e67eaa8ef0d991f7c, 7b2cc00171e...
# 4  [0ca5ad2a218f59eb83eec1e248a0782d, 9869fc8da14...

# %%
reviewers_df.head()
# Out:
#    Username         DOB          State  \
# 0  bkpn1412  31.07.1983         Oregon
# 1  gqjs4414  27.07.1998  Massachusetts
# 2  eehe1434  08.08.1950          Idaho
# 3  hkxj1334  03.08.1969        Florida
# 4  jjbd1412  26.07.2001        Georgia
#
#                                             Reviewed
# 0                 [cea76118f6a9110a893de2b7654319c0]
# 1                 [fa04fe6c0dd5189f54fe600838da43d3]
# 2                                                 []
# 3  [f129b1803f447c2b1ce43508fb822810, 3b0c9bc0be6...
# 4                                                 []

# %% [markdown]
# ## **2.5:  Displaying the structure of each loaded data files**

# %%
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7982 entries, 0 to 7981
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Uniq_id      7982 non-null   object
#  1   SKU          7915 non-null   object
#  2   Name         7982 non-null   object
#  3   Description  7439 non-null   object
#  4   Price        5816 non-null   float64
#  5   Av_Score     7982 non-null   float64
# dtypes: float64(2), object(4)
# memory usage: 374.3+ KB

# %%
reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39063 entries, 0 to 39062
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Uniq_id   39063 non-null  object
#  1   Username  39063 non-null  object
#  2   Score     39063 non-null  int64
#  3   Review    39063 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 1.2+ MB

# %%
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Username  5000 non-null   object
#  1   DOB       5000 non-null   object
#  2   State     5000 non-null   object
# dtypes: object(3)
# memory usage: 117.3+ KB

# %%
products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7982 entries, 0 to 7981
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   uniq_id                 7982 non-null   object
#  1   sku                     7982 non-null   object
#  2   name_title              7982 non-null   object
#  3   description             7982 non-null   object
#  4   list_price              7982 non-null   object
#  5   sale_price              7982 non-null   object
#  6   category                7982 non-null   object
#  7   category_tree           7982 non-null   object
#  8   average_product_rating  7982 non-null   float64
#  9   product_url             7982 non-null   object
#  10  product_image_urls      7982 non-null   object
#  11  brand                   7982 non-null   object
#  12  total_number_reviews    7982 non-null   int64
#  13  Reviews                 7982 non-null   object
#  14  Bought With             7982 non-null   object
# dtypes: float64(1), int64(1), object(13)
# memory usage: 935.5+ KB

# %%
reviewers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Username  5000 non-null   object
#  1   DOB       5000 non-null   object
#  2   State     5000 non-null   object
#  3   Reviewed  5000 non-null   object
# dtypes: object(4)
# memory usage: 156.4+ KB

# %% [markdown]
# ## **2.6:  Checking the Data Files for Missing Values**

# %% [markdown]
# In section 2.5, I observed that all fields for the given datasets are complete, except for the products dataset.
#
# Let's check the **products dataset** for **missing values** in its various fields.

# %%
print("Missing Values in products per column:\n", products.isnull().sum())
# Out:
# Missing Values in products per column:
#  Uniq_id           0
# SKU              67
# Name              0
# Description     543
# Price          2166
# Av_Score          0
# dtype: int64

# %% [markdown]
# ## **2.7:  Key Observation from the Data Set Inspection**

# %% [markdown]
# From the loading and inspection exercise, the datasets are relationally structured, with the **reviews dataset** acting as the **central linking table** via **uniq_id** and **username**.
#
# The missing value assessment shows complete key fields in reviews, users, and both JSON datasets. Although the products dataset has some missing values in sku, price and description, the product IDs (Uniq_ID) and names are complete.
#
# The JSON datasets contain details already available in the CSV files.
#
# Therefore, to *keep the analysis within the context of its aim as stated in the report and within the page limit*, I will use the following datasets:
# *   ***reviews*** for ***central linking table*** and for ***reviews analysis***,
# *   ***products*** for ***product analysis***,
# *   and, ***users*** for ***demographic analysis***.
#
# *The JSON datasets will not be used for carrying out analysis*.

# %% [markdown]
# # **SECTION 3:  Data Preparation**

# %% [markdown]
# ## **3.1: Brief Overview of Section**

# %% [markdown]
# Following dataset inspection and selection, this section prepares the data for analysis by converting all the identifiers across the various data sets into lower case, creating a unified analytical dataset, and creating demographic variables (age and age groups) for segmentation.

# %% [markdown]
# ## **3.2: Checking for Duplicate Rows in the Selected Datasets**

# %%
print("There are", products.duplicated().sum(), "duplicate rows (records) in the products dataset")
# Out:
# There are 0 duplicate rows (records) in the products dataset

# %%
print("There are", reviews.duplicated().sum(), "duplicate rows (records) in the reviews dataset")
# Out:
# There are 0 duplicate rows (records) in the reviews dataset

# %%
print("There are", users.duplicated().sum(), "duplicate rows (records) in the users dataset")
# Out:
# There are 0 duplicate rows (records) in the users dataset

# %% [markdown]
# ## **3.3: Standardising the Column Names**

# %%
# convert column names to lowercase
for df in [products, reviews, users, products_df, reviewers_df]:
    df.columns = df.columns.str.lower()

print(products.columns)
print(reviews.columns)
print(users.columns)
# Out:
# Index(['uniq_id', 'sku', 'name', 'description', 'price', 'av_score'], dtype='object')
# Index(['uniq_id', 'username', 'score', 'review'], dtype='object')
# Index(['username', 'dob', 'state'], dtype='object')

# %% [markdown]
# ## **3.4: Merging the Selected Data Sets**

# %%
# merge reviews with products
merged_ds = pd.merge(reviews, products, on='uniq_id', how='left')

# merge merged_ds with users
merged_ds = pd.merge(merged_ds, users, on='username', how='left')

# %% [markdown]
# ## **3.5: Creating the Demographic Variables**

# %% [markdown]
# ### **3.5.1: Creating the Age Field**

# %%
import datetime

# convert DOB to datetime format (dd.mm.yyyy)
merged_ds['dob'] = pd.to_datetime(merged_ds['dob'], errors='coerce', dayfirst=True)

# calculate the age
current_year = datetime.datetime.now().year
merged_ds['age'] = current_year - merged_ds['dob'].dt.year

# %% [markdown]
# ### **3.5.2: Creating the Age-Group Field**

# %%
bins = [0, 18, 25, 35, 50, 65, 100]
labels = ['<18', '18-25', '26-35', '36-50', '51-65', '65+']

merged_ds['age_group'] = pd.cut(merged_ds['age'], bins=bins, labels=labels)

# %% [markdown]
# ## **3.6: Checking out the Merged Data Set**

# %% [markdown]
# ### **3.6.1: Checking the Data Size**

# %%
merged_ds.head()
# Out:
#                             uniq_id  username  score  \
# 0  b6c0b6bea69c722939585baeac73c13d  fsdv4141      2
# 1  b6c0b6bea69c722939585baeac73c13d  krpz1113      1
# 2  b6c0b6bea69c722939585baeac73c13d  mbmg3241      2
# 3  b6c0b6bea69c722939585baeac73c13d  zeqg1222      0
# 4  b6c0b6bea69c722939585baeac73c13d  nvfn3212      3
#
#                                               review           sku  \
# 0  You never have to worry about the fit...Alfred...  pp5006380337
# 1  Good quality fabric. Perfect fit. Washed very ...  pp5006380337
# 2  I do not normally wear pants or capris that ha...  pp5006380337
# 3  I love these capris! They fit true to size and...  pp5006380337
# 4  This product is very comfortable and the fabri...  pp5006380337
#
#                                           name  \
# 0  Alfred Dunner® Essential Pull On Capri Pant
# 1  Alfred Dunner® Essential Pull On Capri Pant
# 2  Alfred Dunner® Essential Pull On Capri Pant
# 3  Alfred Dunner® Essential Pull On Capri Pant
# 4  Alfred Dunner® Essential Pull On Capri Pant
#
#                                          description  price  av_score  \
# 0  Youll return to our Alfred Dunner pull-on capr...  41.09     2.625
# 1  Youll return to our Alfred Dunner pull-on capr...  41.09     2.625
# 2  Youll return to our Alfred Dunner pull-on capr...  41.09     2.625
# 3  Youll return to our Alfred Dunner pull-on capr...  41.09     2.625
# 4  Youll return to our Alfred Dunner pull-on capr...  41.09     2.625
#
#          dob                     state  age age_group
# 0 1980-07-31            American Samoa   46     36-50
# 1 1987-07-30                  Virginia   39     36-50
# 2 1951-08-08  Northern Mariana Islands   75       65+
# 3 1994-07-28               Connecticut   32     26-35
# 4 1980-07-31                  Oklahoma   46     36-50

# %%
print("Total rows and coulumns repectively in the merged dataset:\n", merged_ds.shape)
# Out:
# Total rows and coulumns repectively in the merged dataset:
#  (39080, 13)

# %% [markdown]
# ### **3.6.2: Checking for Missing Values**

# %%
print("Missing product name:", merged_ds['name'].isnull().sum())
print("Missing username:", merged_ds['username'].isnull().sum())
print("Missing uniq_id:", merged_ds['uniq_id'].isnull().sum())
print("Missing state:", merged_ds['state'].isnull().sum())
print("Missing age:", merged_ds['age'].isnull().sum())
print("Missing age group:", merged_ds['age_group'].isnull().sum())
print("Missing score:", merged_ds['score'].isnull().sum())
# Out:
# Missing product name: 0
# Missing username: 0
# Missing uniq_id: 0
# Missing state: 0
# Missing age: 0
# Missing age group: 0
# Missing score: 0

# %% [markdown]
# ### **3.6.3: Checking for Duplicate Rows (Records)**

# %%
print("The Merged Dataset contains", merged_ds.duplicated().sum(), "Duplicated Rows (Records).")
# Out:
# The Merged Dataset contains 0 Duplicated Rows (Records).

# %% [markdown]
# ## **3.7: Key Insights form the Data Preparation Section**

# %% [markdown]
# In this section, I checked for duplicate rows (records) in the selected datasaet and upon confirming the existence of none, I converted the field names (identifiers) for the selected datasets to lowercase, merged them into a single dataset, and created the necessary demographic data.
#
# A quick inspection of essential fields revealed no empty values and there are no duplicate rows(records), clearing the way to start the analysis process in section 4.

# %% [markdown]
# # **SECTION 4:  Exploratory Data Analysis**

# %% [markdown]
# ### **4.1: Brief Overview of this Section**

# %% [markdown]
# This section examines customer rating patterns and product performance.
#
# I'll start with a quick analysis of the overall rating distribution to assess general satisfaction levels.
#
# Next, I'll identify top ten rated products based on average score rating and review score count. This would also be followed by how these scores are distributed across for the top rated products. I'll also evaluate rating differences across age groups and states to understand demographic and geographic variations in customer satisfaction.

# %% [markdown]
# ### **4.2: Distribution of Customer Rating Score**

# %%
# frequency distribution table for review score count
merged_ds['score'].value_counts().sort_index()
# Out:
# score
# 0    11270
# 1    11690
# 2     7961
# 3     4009
# 4     2247
# 5     1903
# Name: count, dtype: int64

# %%
# bar chart showing how many times each rating score appears in the dataset
plt.figure()
sns.countplot(
    x='score', data=merged_ds,
    hue='score', edgecolor='black',
    palette='hls'
)

plt.title("Distribution of Customer Ratings", fontsize=12, weight= "bold")
plt.xlabel("Rating Score", fontsize=10, weight= "bold")
plt.ylabel("Frequency", fontsize=10, weight= "bold")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### **4.3: Product Performance Analysis for Top 10 Rated Products**

# %%
# average rating and total reviews for each product
product_perf = (
    merged_ds.groupby('name')
    .agg(
        average_score=('score', 'mean'),  # mean score per product
        review_count=('score', 'count')   # total score count per product
    )
    .reset_index()
)

# products with at least 10 reviews
product_perf = product_perf[product_perf['review_count'] >= 10]

# top 10 highest-rated products
top_10_products = product_perf.sort_values(
    'average_score',
    ascending=False
).head(10)

# %%
# table showing top ten products with highest average rating score
# and review count
top_10_products.head(10)
# Out:
#                                                    name  average_score  \
# 1871  GE® ENERGY STAR® 4.3 DOE Cu. ft. High Efficien...       3.062500
# 5546                 Xersion™ Compression Slider Shorts       2.571429
# 881                Call It Spring™ Chaella Ballet Flats       2.562500
# 2454     JCPenney Home™ Stoneware Dinnerware Collection       2.454545
# 2703  Lamont Home® Woven Jacquard Bedspread & Access...       2.437500
# 5134      Total Girl® Bike Shorts - Girls 7-16 and Plus       2.416667
# 1220  Cortland Intimates Back-Support High-Waist Bri...       2.400000
# 2146  Hoover® Tempo™ WidePath® Bagged Upright Vacuum...       2.400000
# 307   Arizona Bootcut Jeans - Boys 8-20, Slim and Husky       2.400000
# 4718  Stafford® 4-pk. Heavyweight Crewneck T-Shirts–...       2.352941
#
#       review_count
# 1871            16
# 5546            14
# 881             16
# 2454            11
# 2703            16
# 5134            12
# 1220            10
# 2146            10
# 307             10
# 4718            17

# %%
# horizontal bar chart showing
# the top 10 highest-rated products based on average score
plt.figure(figsize=(10,6))

sns.barplot(
    x='average_score',
    y='name',
    data=top_10_products,
    edgecolor='black',
    hue='name',
    palette='magma'
)

plt.title("Top 10 Rated Products (Min. 10 Reviews)", fontsize=14, weight= "bold")
plt.xlabel("Average Rating", fontsize=12, weight= "bold")
plt.ylabel("Product Name", fontsize=12, weight= "bold")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### **4.4: Review Rating Score Distribution for Top 10 Rated Products**

# %%
# dataset containing only the top 10 products
top_products_scores = merged_ds[merged_ds['name'].isin(top_10_products['name'])]

# order products by average score (highest first)
order = top_10_products.sort_values('average_score', ascending=False)['name']

# %%
# boxplot showing rating distribution for each top product
plt.figure(figsize=(10,6))

sns.boxplot(
    x='score',
    y='name',
    data=top_products_scores,
    order=order,  # ensures highest average score appears first
    palette='Set2',
    hue='name'
)

plt.title("Review Rating Score Distribution for Top 10 Products", fontsize=12, weight='bold')
plt.xlabel("Review Rating Score", fontsize=10, weight= "bold")
plt.ylabel("Product Name", fontsize=10, weight= "bold")

plt
plt.tight_layout()
plt.show()

# %% [markdown]
# ### **4.5: Average Rating by Age Group**

# %%
# average rating score per age group
age_perf = (
    merged_ds.groupby('age_group', observed=False)['score']
    .mean()
    .reset_index()
)

# %%
# table showing average rating score per age group
age_perf[['age_group', 'score']].head(6)
# Out:
#   age_group     score
# 0       <18       NaN
# 1     18-25  1.424837
# 2     26-35  1.476832
# 3     36-50  1.504593
# 4     51-65  1.490808
# 5       65+  1.476156

# %%
# bar chart showing the average rating score per age group
plt.figure(figsize=(8,5))

sns.barplot(
    x='age_group',
    y='score',
    data=age_perf,
    edgecolor='black',
    hue='age_group',
    palette='flare'
)

plt.title("Average Rating by Age Group", fontsize=12, weight= "bold")
plt.xlabel("Age Group", fontsize=10, weight= "bold")
plt.ylabel("Average Rating", fontsize=10, weight= "bold")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### **4.6: Top 10 States by Average Rating**

# %%
# average rating score per state
state_perf = (
    merged_ds.groupby('state')['score']
    .mean()
    .reset_index()
)

# top ten states with the highest average rating score
top_ten_states = state_perf.sort_values(
    'score',
    ascending=False
).head(10)

# %%
# table showing top ten states with highest average rating score
top_ten_states[['state', 'score']].head(10)
# Out:
#                   state     score
# 16              Indiana  1.603604
# 11              Georgia  1.596376
# 49  U.S. Virgin Islands  1.581173
# 10              Florida  1.579109
# 54        West Virginia  1.577573
# 28             Missouri  1.575301
# 45       South Carolina  1.550847
# 15             Illinois  1.543438
# 52             Virginia  1.540390
# 51              Vermont  1.537349

# %%
# horizontal bar chart showing the top 10 states
# with highest average rating score
sns.barplot(
    x='score',
    y='state',
    data=top_ten_states,
    hue = 'state',
    edgecolor='black',
    palette='mako'
)

plt.title("Top 10 States by Average Rating", fontsize=12, weight= "bold")
plt.xlabel("Average Rating", fontsize=10, weight= "bold")
plt.ylabel("Top 10 States", fontsize=10, weight= "bold")

plt.tight_layout()
plt.show()
